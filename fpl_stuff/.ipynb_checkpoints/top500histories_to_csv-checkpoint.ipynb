# %% [markdown]
# This notebook will pull from the FPL API the weekly results for each player and stack all the results into a single df
#
# Update weekly

# %%
import pandas as pd
import numpy as np
import requests

# %%
top500 = pd.read_csv('top500.csv')
top500.head()
# Out:
#    id_  assists  bonus  bps  chance_of_playing_next_round  \
# 0  166        2     13  287                           NaN
# 1  192        4     11  214                         100.0
# 2  215       10     10  299                         100.0
# 3  460        2     14  251                         100.0
# 4  210        3      6  280                           NaN
#
#    chance_of_playing_this_round  clean_sheets    code  cost_change_event  \
# 0                           NaN             4  101668                  1
# 1                         100.0             3  110979                  1
# 2                         100.0             5   61366                  0
# 3                         100.0             3  173879                  1
# 4                           NaN             2   37572                  0
#
#    cost_change_event_fall  ...  threat  total_points  transfers_in  \
# 0                      -1  ...   363.0            80       1723819
# 1                      -1  ...   364.0            76       1915398
# 2                       0  ...   253.0            74       2915251
# 3                      -1  ...   476.0            73       3501359
# 4                       0  ...   503.0            68       1314669
#
#    transfers_in_event  transfers_out  transfers_out_event  value_form  \
# 0              172078         554853                 5014         1.0
# 1              121049         751463                 5885         0.7
# 2               43848        1412754                29477         0.3
# 3              103919         507938                 7130         0.9
# 4               10804         999591                48525         0.2
#
#    value_season   web_name  yellow_cards
# 0           8.5      Vardy             1
# 1           6.4       Mané             1
# 2           7.3  De Bruyne             0
# 3           9.2    Abraham             2
# 4           5.6     Agüero             0
#
# [5 rows x 53 columns]

# %%
histories = {}

ids = top500['id_']

for id_ in ids:
    url = 'https://fantasy.premierleague.com/api/element-summary/' + str(id_) + '/'
    r = requests.get(url)
    player_data = r.json()
    player_history = player_data['history']
    
    histories[id_] = player_history

# %%
history_dfs = {}

for key in histories:
    df = pd.DataFrame(histories[key])
    df['gameweek'] = [i+1 for i in range((len(df.index)))]
    df['id_'] = key
    df['sum_points'] = [sum(df['total_points'].iloc[:i+1]) for i in range(len(df.index))]
    history_dfs[key] = df

# %%
type(history_dfs)
# Out:
# dict

# %%
top500histories = pd.concat(history_dfs.values(), ignore_index=True)
top500histories.shape
# Out:
# (5379, 34)

# %%
top500histories.to_csv('top500histories.csv')

# %%
top500histories.head()
# Out:
#    assists  bonus  bps  clean_sheets creativity  element  fixture  \
# 0        0      0    5             1        4.9      166        5
# 1        0      0   -3             0        2.3      166       14
# 2        0      2   25             0        1.8      166       27
# 3        1      3   63             0       13.6      166       36
# 4        0      0    5             0       11.3      166       45
#
#    goals_conceded  goals_scored ict_index  ... total_points transfers_balance  \
# 0               0             0       1.6  ...            2                 0
# 1               1             0       0.9  ...            2            -82257
# 2               1             1       6.2  ...            8            -78612
# 3               1             2      14.6  ...           16             -7210
# 4               1             0       1.7  ...            2             83507
#
#    transfers_in  transfers_out  value  was_home  yellow_cards  gameweek  id_  \
# 0             0              0     90      True             0         1  166
# 1         18334         100591     90     False             0         2  166
# 2         32101         110713     89     False             0         3  166
# 3         49194          56404     89      True             0         4  166
# 4        136063          52556     89     False             0         5  166
#
#    sum_points
# 0           2
# 1           4
# 2          12
# 3          28
# 4          30
#
# [5 rows x 34 columns]
