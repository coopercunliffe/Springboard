# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('top500histories.csv', index_col=0)
df.columns
# Out:
# Index(['assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'element',
#        'fixture', 'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves',
#        'selected', 'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'id_'],
#       dtype='object')

# %%
df_totals = pd.read_csv('top500.csv', index_col=0)
df_totals
# Out:
#      assists  bonus  bps  chance_of_playing_next_round  \
# id
# 215        9     10  246                          75.0
# 210        3      6  255                           NaN
# 192        2      8  162                         100.0
# 191        3      7  150                          75.0
# 11         1     10  215                           NaN
# 460        0     11  201                         100.0
# 278        2      9  208                           NaN
# 214        0      4  167                           NaN
# 187        4      9  195                           NaN
# 67         3      4  173                           NaN
# 338        1      7  163                           NaN
# 217        5      6  170                           NaN
# 166        1      8  143                           NaN
# 463        1      6  164                         100.0
# 219        5      3  137                           NaN
# 428        1      7  124                           NaN
# ...
