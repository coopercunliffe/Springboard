# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('top500histories.csv', index_col=0)
df500 = pd.read_csv('top500.csv', index_col=0)
dfteams = pd.read_csv('teams', index_col=0)


df['web_name'] = [df500.loc[i]['web_name'] for i in df['element']]

# %%
df[df['element'] == 11]
# Out:
#     assists  bonus  bps  clean_sheets  creativity  element  fixture  \
# 80        0      0   25             1         6.5       11       10
# 81        0      1   25             0        18.9       11       11
# 82        1      0   17             0        25.3       11       24
# 83        0      3   35             0        26.6       11       31
# 84        0      3   54             0         2.2       11       49
# 85        0      0   26             0         1.6       11       51
# 86        0      3   33             0        25.7       11       67
# 87        0      0    0             1        12.8       11       71
# 88        0      0    7             0         4.7       11       88
# 89        0      0    5             0        12.4       11       91
#
#     goals_conceded  goals_scored  ict_index  ...  total_points  \
# 80               0             1       15.0  ...             6
# 81               1             1        9.4  ...             6
# 82               3             0        5.5  ...             5
# 83               2             1       12.7  ...             9
# 84               2             2       11.5  ...            13
# 85               2             1        9.5  ...             5
# 86               1             1        8.7  ...             9
# 87               0             0        6.1  ...             2
# 88               1             0        1.6  ...             2
# 89               2             0        2.4  ...             2
#
#    transfers_balance  transfers_in  transfers_out  value  was_home  \
# 80                 0             0              0    110     False
# 81            113772        181990          68218    110      True
# 82           -248663         52971         301634    110     False
# 83           -109901         59121         169022    110      True
# 84            -59610         66384         125994    110     False
# 85            117466        158891          41425    110      True
# 86            -30817         72845         103662    110     False
# 87            201560        219717          18157    110      True
# 88            133927        185133          51206    111     False
# 89             52748        105976          53228    111      True
#
#     yellow_cards  gameweek  sum_points    web_name
# 80             0         1           6  Aubameyang
# 81             1         2          12  Aubameyang
# 82             0         3          17  Aubameyang
# 83             0         4          26  Aubameyang
# 84             0         5          39  Aubameyang
# 85             1         6          44  Aubameyang
# 86             0         7          53  Aubameyang
# 87             0         8          55  Aubameyang
# 88             0         9          57  Aubameyang
# 89             0        10          59  Aubameyang
#
# [10 rows x 34 columns]

# %%
top10 = df.iloc[:60]
sns.set()
plt.figure(figsize=(24, 6))
plt.title('Points Each Week')
sns.lineplot(data=top10, x='gameweek', y='total_points', hue='web_name', markers=True)
plt.show()

# %%
top10 = df.iloc[:60]
sns.set()
plt.figure(figsize=(24, 6))
plt.title('Accumulated Points')
sns.lineplot(data=top10, x='gameweek', y='sum_points', hue='web_name')
plt.show()
