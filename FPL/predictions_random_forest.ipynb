# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_csv('top500histories.csv', index_col=0)
raw.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element  fixture  \
# 0        0      0    5             1         4.9      166        5
# 1        0      0   -3             0         2.3      166       14
# 2        0      2   25             0         1.8      166       27
# 3        1      3   63             0        13.6      166       36
# 4        0      0    5             0        11.3      166       45
#
#    goals_conceded  goals_scored  ict_index  ...  transfers_in transfers_out  \
# 0               0             0        1.6  ...             0             0
# 1               1             0        0.9  ...         18334        100591
# 2               1             1        6.2  ...         32101        110713
# 3               1             2       14.6  ...         49194         56404
# 4               1             0        1.7  ...        136063         52556
#
#    value  was_home  yellow_cards  gameweek  id_  sum_points  web_name  \
# 0     90      True             0         1  166           2     Vardy
# 1     90     False             0         2  166           4     Vardy
# 2     89     False             0         3  166          12     Vardy
# 3     89      True             0         4  166          28     Vardy
# 4     89     False             0         5  166          30     Vardy
#
#    next_week_points
# 0                 2
# 1                 8
# 2                16
# 3                 2
# 4                 2
#
# [5 rows x 36 columns]

# %%
raw_sorted = raw.sort_values('gameweek')

# %%
df = raw_sorted[['id_', 'web_name', 'gameweek', 'goals_scored', 'assists', 'clean_sheets', 'bps', 'saves', 'minutes', 'sum_points', 'next_week_points']]
df.head()
# Out:
#       id_      web_name  gameweek  goals_scored  assists  clean_sheets  bps  \
# 0     166         Vardy         1             0        0             1    5
# 7611  412         Ruddy         1             0        0             0    0
# 2397  380    Fredericks         1             0        0             0   11
# 7606  563  Dele-Bashiru         1             0        0             0    0
# 2414  254     Fernández         1             0        0             0    0
#
#       saves  minutes  sum_points  next_week_points
# 0         0       90           2                 2
# 7611      0        0           0                 0
# 2397      0       90           0                 2
# 7606      0        0           0                 0
# 2414      0        0           0                 0
