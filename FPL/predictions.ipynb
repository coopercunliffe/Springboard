# %%
import pandas as pd
import numpy as np

df = pd.read_csv('top500histories.csv', index_col=0)
df1819 = pd.read_csv('df1819', index_col=0)
df_now = pd.read_csv('top500.csv')

df1819.shape

df_now.sort_values('total_points', ascending=False)[['web_name', 'total_points']].loc[:250]
# Out:
#       web_name  total_points
# 0        Vardy           104
# 1         Mané            92
# 2    De Bruyne            83
# 3      Abraham            83
# 4     Rashford            74
# ..         ...           ...
# 256     Aarons            16
# 255    Godfrey            16
# 253      Praet            16
# 254    Nakamba            16
# 250  Longstaff            16
#
# [253 rows x 2 columns]

# %%
 df.head()
# Out:
#    element  fixture  opponent_team  total_points  was_home  \
# 0      166        5             20             2      True
# 1      166       14              6             2     False
# 2      166       27             15             8     False
# 3      166       36              3            16      True
# 4      166       45             12             2     False
#
#            kickoff_time  team_h_score  team_a_score  round  minutes  ...  \
# 0  2019-08-11T13:00:00Z             0             0      1       90  ...
# 1  2019-08-18T15:30:00Z             1             1      2       90  ...
# 2  2019-08-24T14:00:00Z             1             2      3       90  ...
# 3  2019-08-31T14:00:00Z             3             1      4       90  ...
# 4  2019-09-14T14:00:00Z             1             0      5       90  ...
#
#    ict_index  value  transfers_balance  selected  transfers_in  transfers_out  \
# 0        1.6     90                  0    586801             0              0
# ...

# %%
df1819[df1819.element == 402]
# Out:
# 38

# %%
df1819.sort_values('total_points', ascending=False)[[
    'name', 'element', 'fixture', 'total_points', 'goals_scored', 'assists', 'bps', 'bonus',
    'kickoff_time', 'opponent_team', 'team_h_score', 'team_a_score', 
    'was_home', 'saves' ]].head()
# Out:
#                                      name  element  fixture  total_points  \
# 14691                 Gerard_Deulofeu_394      394      264            23
# 9481                    Heung-Min_Son_367      367      175            21
# 18812  Lucas_Rodrigues Moura da Silva_370      370      339            21
# 16691                 Raheem_Sterling_270      270      298            21
# 12291                    Fabian_Schär_482      482      227            21
#
#        goals_scored  assists  bps  bonus          kickoff_time  opponent_team  \
# 14691             3        1   81      3  2019-02-22T19:45:00Z              5
# 9481              2        2   71      3  2018-12-23T16:00:00Z              8
# 18812             3        0   65      3  2019-04-13T11:30:00Z             10
# 16691             3        0   65      3  2019-03-09T17:30:00Z             18
# 12291             2        0   50      3  2019-01-19T15:00:00Z              5
#
#        team_h_score  team_a_score  was_home  saves
# ...
